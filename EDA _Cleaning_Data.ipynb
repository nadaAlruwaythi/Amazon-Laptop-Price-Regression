# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime as dt
import pickle
from scipy import stats
import seaborn as sns
import math 
import random
from sqlalchemy import create_engine
import datetime
from sklearn.linear_model import LinearRegression
import patsy

# %%
df = pd.read_csv('DF1 (1).csv',sep=',')
df.head(2)
# Out:
#    Brand Standing screen display size Processor Brand Processor Speed  \
# 0  Apple                         13.3           Intel             2.3
# 1  Apple                         13.3           Intel             1.8
#
#   RAM Size Hard Drive Size Hard Disk Description Graphics Chipset Brand  \
# 0        8             128                  SSD                   Intel
# 1        8             128          FlashStorage                  Intel
#
#   Operating System  Item Weight      Price
# 0            macOS         1.37  5827.6515
# 1            macOS         1.34  3910.3890

# %%
df.tail()
# Out:
#            Brand Standing screen display size Processor Brand Processor Speed  \
# 1741  ?Microsoft                           13            ?AMD            ?1.8
# 1742         ?HP                           14          ?Intel            ?1.8
# 1743         ?HP                         15.6          ?Intel            ?1.8
# 1744         ?HP                         15.6            ?AMD              ?2
# 1745         ?HP                           13            ?AMD            ?1.8
#
#      RAM Size Hard Drive Size Hard Disk Description Graphics Chipset Brand  \
# 1741      ?16            ?256                 ?SSD                    ?AMD
# 1742      ?16            ?512                 ?SSD                  ?Intel
# 1743      ?16            ?512                 ?SSD                  ?Intel
# 1744      ?16            ?256                 ?SSD                    ?AMD
# 1745      ?16            ?256                 ?SSD                    ?AMD
#
#      Operating System  Item Weight    Price
# 1741    ?Windows10Pro         1.70  4842.91
# 1742    ?Windows10Pro         1.70  6222.22
# 1743    ?Windows10Pro         9.03  6411.22
# 1744    ?Windows10Pro         1.81  4442.91
# 1745    ?Windows10Pro         1.70  4842.91

# %%
df.sample(5)
# Out:
#        Brand Standing screen display size Processor Brand Processor Speed  \
# 1345   ?Asus                         15.6          ?Intel            ?2.5
# 885       HP                         13.3           Intel             2.5
# 1620     ?HP                         13.5            ?AMD            ?2.1
# 341   Lenovo                         15.6             AMD             3.6
# 1026      HP                           14           Intel             2.5
#
#      RAM Size Hard Drive Size Hard Disk Description Graphics Chipset Brand  \
# 1345       ?8            ?256                  SSD                 ?Nvidia
# 885         4             256                  SSD                   Intel
# 1620      ?32           ?1000                 ?SSD                    ?AMD
# 341        12            2000                   HDD                    AMD
# 1026        4             500                   HDD                  Intel
#
#      Operating System  Item Weight    Price
# 1345       ?Windows10         2.72  3028.47
# 885         Windows10         1.28  7825.65
# 1620       ?Windows11         2.30  4244.96
# 341         Windows10         2.20  3910.65
# 1026        Windows10         2.31  5172.15

# %%
df.shape
# Out:
# (1746, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746 entries, 0 to 1745
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Brand                         1746 non-null   object
#  1   Standing screen display size  1746 non-null   object
#  2   Processor Brand               1746 non-null   object
#  3   Processor Speed               1736 non-null   object
#  4   RAM Size                      1746 non-null   object
#  5   Hard Drive Size               1745 non-null   object
#  6   Hard Disk Description         1746 non-null   object
#  7   Graphics Chipset Brand        1744 non-null   object
#  8   Operating System              1746 non-null   object
#  9   Item Weight                   1746 non-null   float64
#  10  Price                         1746 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 150.2+ KB

# %%
df.columns = [column.strip() for column in df.columns]

# %%
df=df.drop_duplicates(subset=['Brand', 'Standing screen display size', 'Processor Brand','Processor Speed', 'RAM Size', 'Hard Drive Size','Hard Disk Description', 'Graphics Chipset Brand', 'Operating System','Item Weight', 'Price'])

# %%
df.dropna(axis=0, how="any", thresh=None, subset=None, inplace=True)
# Out:
# NumExpr defaulting to 8 threads.

# %%
df.reset_index(drop=True ,inplace=True)

# %%
for i in range(1681):
    df['Brand'].iloc[i]=df['Brand'].iloc[i].strip('?')
    df['Processor Brand'].iloc[i]=df['Processor Brand'].iloc[i].strip('?')
    df['Standing screen display size'].iloc[i]=float(df['Standing screen display size'].iloc[i].strip('?'))
    df['Processor Speed'].iloc[i]=float(df['Processor Speed'].iloc[i].strip('?'))
    df['RAM Size'].iloc[i]=float(df['RAM Size'].iloc[i].strip('?'))
    df['Hard Drive Size'].iloc[i]=float(df['Hard Drive Size'].iloc[i].strip('?'))
    df['Hard Disk Description'].iloc[i]=df['Hard Disk Description'].iloc[i].strip('?')
    df['Graphics Chipset Brand'].iloc[i]=df['Graphics Chipset Brand'].iloc[i].strip('?')
    df['Operating System'].iloc[i]=df['Operating System'].iloc[i].strip('?')
df['Standing screen display size']=df['Standing screen display size'].astype(float)
df['Processor Speed']=df['Processor Speed'].astype(float)
print('Done converting')
# Out:
# C:\Users\nadaa\anaconda3\anaconda\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Done converting

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1681 entries, 0 to 1680
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Brand                         1681 non-null   object
#  1   Standing screen display size  1681 non-null   float64
#  2   Processor Brand               1681 non-null   object
#  3   Processor Speed               1681 non-null   float64
#  4   RAM Size                      1681 non-null   object
#  5   Hard Drive Size               1681 non-null   object
#  6   Hard Disk Description         1681 non-null   object
#  7   Graphics Chipset Brand        1681 non-null   object
#  8   Operating System              1681 non-null   object
#  9   Item Weight                   1681 non-null   float64
#  10  Price                         1681 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 144.6+ KB

# %%
df['Brand'].value_counts()
# Out:
# HP              417
# Lenovo          409
# Dell            292
# Asus            251
# Acer            101
# MSI              54
# Toshiba          48
# Oemgenuine       29
# Apple            21
# Microsoft        12
# Samsung           8
# Razer             7
# Mediacom          7
# Xiaomi            4
# Vero              3
# LG                3
# Google            3
# Chuwi             3
# Fujitsu           3
# SHOXLAB           2
# Huawei            2
# LenovoLaptop      1
# Basrdis           1
# Name: Brand, dtype: int64

# %%
df.tail()
# Out:
#           Brand  Standing screen display size Processor Brand  \
# 1676  Microsoft                          13.0             AMD
# 1677         HP                          14.0           Intel
# 1678         HP                          15.6           Intel
# 1679         HP                          15.6             AMD
# 1680         HP                          13.0             AMD
#
#       Processor Speed RAM Size Hard Drive Size Hard Disk Description  \
# 1676              1.8       16             256                  SSD
# 1677              1.8       16             512                  SSD
# 1678              1.8       16             512                  SSD
# 1679              2.0       16             256                  SSD
# 1680              1.8       16             256                  SSD
#
#      Graphics Chipset Brand Operating System  Item Weight    Price
# 1676                    AMD     Windows10Pro         1.70  4842.91
# 1677                  Intel     Windows10Pro         1.70  6222.22
# 1678                  Intel     Windows10Pro         9.03  6411.22
# 1679                    AMD     Windows10Pro         1.81  4442.91
# 1680                    AMD     Windows10Pro         1.70  4842.91

# %%
#remove outliers
cols=['Brand', 'Standing screen display size', 'Processor Brand',
       'Processor Speed', 'RAM Size', 'Hard Drive Size',
       'Hard Disk Description', 'Graphics Chipset Brand', 'Operating System',
       'Item Weight', 'Price']

# %%
#delete outliers
Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
IQR = Q3 - Q1

result = df[~((df[cols] < (Q1 - 1.5 * IQR)) |(df[cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
result.shape
# Out:
# (1469, 11)

# %% [markdown]
# # Visualization

# %%
plt.subplots(figsize=(20,10))
sns.barplot(x='Brand',y='Price',data=result)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Price'>

# %%
plt.subplots(figsize=(20,10))
sns.barplot(x='Graphics Chipset Brand',y='Price',data=result)
# Out:
# <AxesSubplot:xlabel='Graphics Chipset Brand', ylabel='Price'>

# %%
plt.subplots(figsize=(20,10))
sns.barplot(x='Standing screen display size',y='Price',data=result)
# Out:
# <AxesSubplot:xlabel='Standing screen display size', ylabel='Price'>

# %%
sns.pairplot(result, height=1.2, aspect=1.5);

# %%
plt.figure(figsize=(20,9))
plt.bar(result.Brand,result.Price)
plt.xlabel('Brand',fontsize=12,family = 'fantasy')
plt.ylabel('Price',fontsize=12,family = 'fantasy')
plt.title('Bran and Price Average',family = 'fantasy',fontsize=20,weight='bold',rotation=0.17)
plt.grid()

# %% [markdown]
# * _Visualizing the relationship between target variable and features_

# %%
subset1=result[[ 'Price', 'Standing screen display size', 'Processor Speed', 'Item Weight', 'Brand', 'Operating System']]

sns.pairplot(subset1, diag_kind='kde')
plt.show();

# %%
result.corr()
# Out:
#                               Standing screen display size  Processor Speed  \
# Standing screen display size                      1.000000         0.114791
# Processor Speed                                   0.114791         1.000000
# Item Weight                                       0.752456         0.204478
# Price                                            -0.168963         0.260897
#
#                               Item Weight     Price
# Standing screen display size     0.752456 -0.168963
# Processor Speed                  0.204478  0.260897
# Item Weight                      1.000000 -0.140371
# Price                           -0.140371  1.000000

# %%
sns.heatmap(result.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1);

# %%
result.to_csv("clean_data.csv")
